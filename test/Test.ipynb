# %%
from PyAudit.basics import missing_rate, zero_rate
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a0bf714a51fd> in <module>
# ----> 1 from PyAudit.basics import missing_rate, zero_rate
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'PyAudit'
